# %%
#task 2 - Superstore_USA
1 . load this data in sql and in pandas with a relation in sql 
2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins 

submit your git link for the same 
 
you have to submit this task by next Friday 5th 11PM IST  to respective mail id 
sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %%
import pandas as pd

# %%
dfo=pd.read_excel(r'D:\Learnings\INeuronDS\neuroni_Live\pandasDS\Data set\data fsds -20220724T095055Z-001\data fsds\Task31\Dataset\task -20220731T125827Z-001\task\Superstore_USA.xlsx')

# %%
dfr=pd.read_excel(r'D:\Learnings\INeuronDS\neuroni_Live\pandasDS\Data set\data fsds -20220724T095055Z-001\data fsds\Task31\Dataset\task -20220731T125827Z-001\task\Superstore_USA.xlsx',sheet_name='Returns')

# %%
dfr
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
dfu=pd.read_excel(r'D:\Learnings\INeuronDS\neuroni_Live\pandasDS\Data set\data fsds -20220724T095055Z-001\data fsds\Task31\Dataset\task -20220731T125827Z-001\task\Superstore_USA.xlsx',sheet_name='Users')

# %%
dfu
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
df.to_csv('Superstore_USA1')

# %%
pwd
# Out:
# 'C:\\Users\\anil.kumar\\jupyter_ineuron_workspace\\neuron_Liveclasses\\Live Resources Assignments'

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
dfr
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
replacements = {
        'timedelta64[ns]': 'varchar(30)',
        'object': 'varchar(30)',
        'float64': 'float(20)',
        'int64': 'int(10)',
        'datetime64[ns]': 'timestamp'
    }

# %%
replacements
# Out:
# {'timedelta64[ns]': 'varchar(30)',
#  'object': 'varchar(30)',
#  'float64': 'float(20)',
#  'int64': 'int(50)',
#  'datetime64[ns]': 'timestamp'}

# %%
#please remove spaces in columns
and -
PENDING

# %%
col_str = ", ".join("{} {}".format(n, d) for (n, d) in zip(dfr.columns, dfr.dtypes.replace(replacements)))
col_str
# Out:
# 'Order ID int(10), Status varchar(30)'

# %%
#Establishing a connection from local to DB
import  mysql.connector as conn


mydb=conn.connect(host = "localhost" , user ="root" , passwd = "ZAQwe@321",use_pure=True )
cursor=mydb.cursor()
# query1="create database PandasAssignmentDB31st"
# cursor.execute(query1)
cursor.execute("show databases")
print(cursor.fetchall())
# Out:
# [('24thassignmenttask',), ('anil',), ('anil1',), ('anildatabase',), ('classicmodels',), ('ineuron',), ('information_schema',), ('mydb',), ('mydb1',), ('mysql',), ('pandasassignmentdb31st',), ('performance_schema',), ('sakila',), ('sudhanshu',), ('sudhanshu2',), ('sudhanshu5',), ('sys',), ('world',)]

# %%
cursor.execute("drop table if exists pandasassignmentdb31st.Superstorer_USA")

# %%
query1='''create table if not exists pandasassignmentdb31st.Superstore_USA(
RowID int(10),
OrderPriority varchar(30), 
Discount float(20), 
UnitPrice float(20), 
ShippingCost float(20), 
CustomerID int(10), 
CustomerName varchar(30), 
ShipMode varchar(30), 
CustomerSegment varchar(30), 
ProductCategory varchar(30), 
ProductSub_Category varchar(30), 
ProductContainer varchar(30), 
ProductName varchar(80), 
ProductBaseMargin float(20), 
Region varchar(30), 
StateProvince varchar(50), 
City varchar(30), 
PostalCode int(10), 
OrderDate timestamp, 
ShipDate timestamp, 
Profit float(20), 
Quantityordered_new int(10), 
Sales float(20), 
OrderID int(10))'''

# %%
cursor.execute(query1)

# %%
query2='''create table if not exists pandasassignmentdb31st.Superstorer_USA(
OrderID int(10), 
Status varchar(30))'''

# %%
cursor.execute(query2)

# %%
#Executed SQL 
SHOW GLOBAL VARIABLES LIKE 'local_infile';
 SET GLOBAL local_infile=1;
 
alter table superstore_usa change ProductName ProductName longtext;

LOAD DATA INFILE 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/Superstore1_USA.csv'
INTO TABLE superstore_usa
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\r\n'
IGNORE 1 ROWS;

SHOW VARIABLES LIKE "secure_file_priv";
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#Order data 
dfo
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#user data
dfu
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#return data
dfr
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
3 . Find out how return that we ahve recived and with a product id

# %%
dfr
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
Order_returns=pd.merge(dfr,dfo)

# %%
Order_returns
# Out:
#     Order ID    Status  Row ID Order Priority  Discount  Unit Price  \
# 0        612  Returned      95         Medium      0.10        5.28
# 1        612  Returned      96         Medium      0.01       65.99
# 2       4610  Returned     653            Low      0.09        8.33
# 3       4610  Returned     654            Low      0.08       15.67
# 4       7079  Returned     979         Medium      0.01      280.98
# ..       ...       ...     ...            ...       ...         ...
# 93     57638  Returned    8079            Low      0.09      217.85
# 94     57638  Returned    8080            Low      0.07       11.48
# 95     57638  Returned    8081            Low      0.08        2.08
# 96     59009  Returned    8251       Critical      0.02       30.98
# 97     59937  Returned    8389           High      0.02       30.98
#
#     Shipping Cost  Customer ID     Customer Name       Ship Mode  ...  \
# 0            6.26         3011      Tammy Raynor     Regular Air  ...
# ...

# %%
mergedata=pd.DataFrame(Order_returns)

# %%
mergedata.columns
# Out:
# Index(['Order ID', 'Status', 'Row ID', 'Order Priority', 'Discount',
#        'Unit Price', 'Shipping Cost', 'Customer ID', 'Customer Name',
#        'Ship Mode', 'Customer Segment', 'Product Category',
#        'Product Sub-Category', 'Product Container', 'Product Name',
#        'Product Base Margin', 'Region', 'State or Province', 'City',
#        'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales'],
#       dtype='object')

# %%
mergedata[(mergedata['Status']=='Returned')]['Order ID']#There are total 98 orders which were returned
#In the question, Product ID is mentioned which is not available, So I have given the order ID instead.
# Out:
# 0       612
# 1       612
# 2      4610
# 3      4610
# 4      7079
#       ...
# 93    57638
# 94    57638
# 95    57638
# 96    59009
# 97    59937
# Name: Order ID, Length: 98, dtype: int64

# %%
4 . try  to join order and return data both in sql and pandas

# %%
pd.merge(dfo,dfr)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#Sql join is pending due to need to create returns table inside  

#need to insert a data into table 
#need to perform join operation

# %%
import pandas as pd
from sqlalchemy import create_engine as ce

# %%
import  mysql.connector as conn
mydb=conn.connect(host = "localhost" , user ="rootuser" , passwd = "rootuser",use_pure=True )
cursor=mydb.cursor()
print(cursor.fetchall)
# Out:
# <bound method MySQLCursor.fetchall of <mysql.connector.cursor.MySQLCursor object at 0x0000017A5B8D8AF0>>

# %%
#Engine Creation to load returns data into mysql
mysql_engine = ce('mysql+pymysql://rootuser:rootuser@localhost:3306/pandasassignmentdb31st')

# %%
dfr.to_sql('superstorer1_usa', mysql_engine)

# %%
#to load users data 
mysql_engine = ce('mysql+pymysql://rootuser:rootuser@localhost:3306/pandasassignmentdb31st')

# %%
dfu.to_sql('superstoreu_usa', mysql_engine)

# %%
dfu
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
5 . Try to find out how many unique customer that we have

# %%
dfo.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
total=dfo['Customer ID'].unique()

# %%
len(total)
# Out:
# 2703

# %%
#6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
dfu
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
dfu[['Region','Manager']].count()
# Out:
# Region     4
# Manager    4
# dtype: int64

# %%
Both_orderandusers=pd.merge(dfo,dfu)

# %%
Both_orderandusers
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      24844         Medium      0.09       78.69          19.99           14
# 2      24846         Medium      0.08        3.28           2.31           14
# 3      24847         Medium      0.05        3.28           4.20           14
# 4      24848         Medium      0.05        3.58           1.63           14
# ...      ...            ...       ...         ...            ...          ...
# 9421   25689       Critical      0.10        4.98           4.70         3381
# 9422   26152  Not Specified      0.00       58.14          36.61         3382
# 9423   26153  Not Specified      0.00       29.99           5.50         3382
# 9424   26154  Not Specified      0.03       16.16           7.74         3382
# 9425   26140  Not Specified      0.04        5.98           7.15         3382
#
# ...

# %%
#7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
dfo['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
Totalnum_shipmode=dfo['Ship Mode'].unique()

# %%
dfo['Ship Mode'].describe()
# Out:
# count            9426
# unique              3
# top       Regular Air
# freq             7036
# Name: Ship Mode, dtype: object

# %%
# Out:
# numpy.ndarray

# %%
Total_count=dfo['Ship Mode'].count().mean()

# %%
total_shipcount=pd.Series(Totalnum_shipmode).count()

# %%
((Total_count)/total_shipcount)*100
# Out:
# 314200.0

# %% [markdown]
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
dfo['differenceinordership']=dfo['Ship Date']-dfo['Order Date']

# %%
dfo
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
difference=dfo['differenceinordership']

# %%
difference
# Out:
# 0      2 days
# 1      1 days
# 2      1 days
# 3      1 days
# 4      0 days
#         ...
# 9421   1 days
# 9422   0 days
# 9423   2 days
# 9424   3 days
# 9425   2 days
# Name: differenceinordership, Length: 9426, dtype: timedelta64[ns]

# %%
dfo[(dfo['differenceinordership'].dt.components['days']>10)]['Order ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %%
#10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
all_data = pd.concat([dfo,dfr])

# %%
pd.merge(dfo,dfr)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
all_data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'differenceinordership',
#        'Status'],
#       dtype='object')

# %%
dfo[dfo['differenceinordership'].dt.components['days']>15]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# ...

# %% [markdown]
# 11 . Gorup by region and find out which region is more profitable

# %%
Allregiondata=pd.merge(dfo,dfu)

# %%
Allregiondata.groupby('Region').max('Profit')
# Out:
#          Row ID  Discount  Unit Price  Shipping Cost  Customer ID  \
# Region
# Central   26387      0.25     3499.99         164.73         3399
# East      26389      0.10     6783.02         110.20         3402
# South     26399      0.10     6783.02          99.00         3382
# West      26397      0.10     6783.02         110.20         3403
#
#          Product Base Margin  Postal Code      Profit  Quantity ordered new  \
# Region
# Central                 0.85        79907  12504.9045                   148
# East                    0.85        45840   9228.2256                   167
# South                   0.85        72956  16332.4140                    97
# West                    0.85        99362   8917.7187                   170
#
#              Sales  Order ID
# Region
# Central   32589.59     91582
# East      48418.58     91591
# South     40136.93     91589
# West     100119.16     91588

# %% [markdown]
# 12 . Try to find out overalll in which country we are giving more didscount

# %%
dfo.groupby('City').max('Discount')
# Out:
#             Row ID  Discount  Unit Price  Shipping Cost  Customer ID  \
# City
# Aberdeen     25523      0.10      300.98          64.73         2617
# Abilene      23405      0.10      212.60          52.20          825
# Abington     18579      0.08       20.15           8.99         1924
# Acton        24626      0.00        4.82           1.49          986
# Addison      22805      0.10       20.99           2.50         3211
# ...            ...       ...         ...            ...          ...
# York         25488      0.09      135.99          28.63         2566
# Youngstown   22142      0.09       55.48           7.96         1592
# Yuba City    23404      0.01       58.14          36.61         1042
# Yucaipa      25581      0.06     2550.14          54.92         1112
# Yuma         24136      0.09      574.74          36.61         1118
#
#             Product Base Margin  Postal Code      Profit  \
# City
# Aberdeen                   0.56        57401  1230.31140
# ...

# %% [markdown]
# 13 . Give me a list of unique postal code

# %%
dfo['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %% [markdown]
# 14 . which customer segement is more profitalble find it out .

# %%
dfo.groupby('Customer Name').max('profit')
# Out:
#                        Row ID  Discount  Unit Price  Shipping Cost  \
# Customer Name
# Aaron Davies Bruce      21011      0.07      194.30          11.54
# Aaron Day               23604      0.06       65.99          16.36
# Aaron Dillon            22062      0.10       11.58           6.97
# Aaron Fuller Davidson   25849      0.10       44.43          46.59
# Aaron Riggs             23202      0.10      179.29          29.21
# ...                       ...       ...         ...            ...
# Zachary House           25405      0.08      140.81          24.49
# Zachary Maynard         26229      0.10      226.67          28.16
# Zachary Potter          23691      0.06      179.99          70.20
# Zachary Wu              25260      0.01      179.29          29.21
# Zachary Yu              18207      0.06       20.99           2.50
#
#                        Customer ID  Product Base Margin  Postal Code  \
# Customer Name
# ...

# %%
#15 . try to find out the 10th most loss making product catagory . 
dfo.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'differenceinordership'],
#       dtype='object')

# %%
#15. try to find out the 10th most loss making product catagory . 
dfo.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
